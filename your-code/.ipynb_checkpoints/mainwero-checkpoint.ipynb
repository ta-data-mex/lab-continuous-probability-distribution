# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
from scipy.stats import uniform

# %%
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.99972982 2.40677417 2.15324838 2.66682721 2.19194965 2.8221139
#  2.34584065 2.9193227  2.96326476 2.61198284]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
# your code here
def generador(a,b,count):
    x = uniform.rvs(size = count)
    randoms  = a + (b-a)*x
    return randoms

# %%
distribucion1 = generador(10,15,100)
distribucion1
# Out:
# array([13.31992811, 14.62389546, 10.98401514, 11.95191284, 10.92101658,
#        11.13906408, 13.34342535, 11.41812343, 11.57198212, 10.61197842,
#        10.59472398, 11.25304616, 10.91150636, 10.57002809, 14.42366809,
#        11.07709734, 11.00604528, 12.8079103 , 14.65559334, 14.82494566,
#        14.98905293, 11.55829653, 14.2198002 , 12.54391056, 14.17935936,
#        10.41063504, 13.3016976 , 13.59399323, 12.31439691, 14.93869352,
#        11.62237964, 12.33147587, 12.66719314, 10.60304766, 10.70629676,
#        12.8778737 , 12.88909783, 10.29175165, 14.23886613, 14.89817012,
#        14.95967515, 11.4943441 , 14.77436704, 11.61541649, 10.68690806,
#        13.39806925, 11.92376253, 11.54642443, 12.35699115, 12.29255836,
#        14.84003108, 12.26344687, 13.25216182, 11.64398402, 14.95786063,
#        12.9009718 , 14.41124681, 13.96937781, 14.35530895, 12.28027941,
#        11.64932892, 12.66564181, 14.78211056, 14.5445658 , 13.93778149,
# ...

# %%
distribucion2 = generador(10, 60, 1000)
distribucion2

# %%
import seaborn as sns

# %%
sns.distplot(distribucion1, bins=10)
sns.distplot(distribucion2, bins=10)

# %%
sns.distplot(distribucion1, bins=10)

# %%
sns.distplot(distribucion2, bins=10)

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below
# Ambas graficas, definen un techo diferente y también una cantidad de datos diferente, con lo cual se hace al juntar las dos graficas,
#muy evidente  el porque se ven tan disparejas

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
# your code here
import scipy.stats
def anormal(mean, stdv):
    numeritos = [scipy.stats.norm.rvs(loc=mean, scale=stdv) for x in range(1000)]
    return numeritos

# %%
sns.set(style="ticks")
sns.distplot(anormal(10,50), kde=False)
sns.distplot(anormal(10,1), kde=False)

# %% [markdown]
# How are the two distributions different?

# %%
sns.distplot(anormal(10,50),kde=False)

# %%
sns.distplot(anormal(10,1), kde=False)

# %%
# your answer below
#Las graficas son similares, respetan ambas a la distribución normal, la diferencia radica en la desviacion standard que permite
#la dispersion de los datos y por eso se ve una mas angosta que la otra

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
# your code here
import pandas as pandito

# %%
vehicular = pandito.read_csv('vehicles.csv')

# %%
sns.distplot(vehicular['Fuel Barrels/Year'] , kde=False)

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
# your code here
sns.distplot(vehicular['CO2 Emission Grams/Mile'] , kde=False)

# %% [markdown]
# 3. Combined MPG

# %%
# your code here
sns.distplot(vehicular['Combined MPG'] , kde=False)

# %%
sns.distplot(vehicular['Fuel Barrels/Year'] , kde=False)
sns.distplot(vehicular['Combined MPG'] , kde=False)
sns.distplot(vehicular['CO2 Emission Grams/Mile'] , kde=False)

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
# your answer here
#Ninguna de las graficas anteriores se ven como un a distribucion uniforme

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 1 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
# your code here
def exponencial(scale, size):
    algo = numpy.random.exponential(scale, size)
    return algo

# %%
uno = exponencial(1,1000)
dos = exponencial(100, 1000)
sns.distplot(uno, bins =100, kde=False)

# %%
sns.distplot(dos, bins =100, kde=False)

# %% [markdown]
# How are the two distributions different?

# %%
# your answer here
# ambas son diferentes puesto que la escala difiere, no es lo mismo tener de valores random hasta 1 a tener valores random hasta 100

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
# your answer here
# Hint: This is same as saying P(x<15)
from scipy.stats import expon
s_time_bank = expon(scale=10).cdf(15)
s_time_bank
# Out:
# 0.7768698398515702

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
1-s_time_bank
# Out:
# 0.2231301601484298

# %%
# your answer here
