# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
from scipy.stats import uniform
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.88848944 2.12046695 2.78566291 2.25222579 2.22710896 2.86159489
#  2.70819552 2.96218175 2.34086116 2.19985569]

# %%
import numpy as np

# The numpy way
randoms_np = np.random.uniform(2,3,(1,10))
print(randoms_np.tolist()[0])
# Out:
# [2.2086692420930922, 2.8296857871145087, 2.116671333778193, 2.2580231102544763, 2.3348258042204653, 2.7690857150733237, 2.228834523434072, 2.554090611451194, 2.8027740135002452, 2.224596555784604]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
# your code here
urng = lambda ll, ul, n : np.random.uniform(ll,ul,n)

# %%
# bottom=10, ceiling=15, count=100
urng(10, 15, 100)
# Out:
# array([14.60388575, 12.15449656, 13.26562365, 12.19972254, 14.31477082,
#        12.21753707, 13.84181976, 12.77742649, 11.06356433, 13.12000877,
#        10.47558514, 11.79002926, 13.67547784, 12.78595066, 13.13006094,
#        10.11925362, 10.49766313, 12.9858608 , 13.26387162, 12.9182161 ,
#        12.89738983, 12.03218904, 11.80139289, 14.19612905, 11.32063868,
#        13.81959402, 10.32724502, 11.64760726, 13.60183651, 11.75548769,
#        11.55988415, 11.39347149, 10.43247486, 14.5198318 , 13.14333949,
#        12.81849496, 13.6832216 , 13.77374347, 12.72192736, 13.04326528,
#        11.90748454, 11.37314499, 14.90783632, 12.56839607, 13.26946982,
#        11.93571856, 12.28785499, 14.49892175, 14.00838685, 13.29133238,
#        14.8464554 , 14.54039732, 11.79900072, 10.04604397, 13.74290461,
#        10.47526845, 10.28690765, 11.94760142, 11.14781948, 10.66966659,
#        13.66902854, 11.21813449, 13.71595209, 10.5274782 , 13.64083666,
# ...

# %%
# bottom=10, ceiling=60, count=1000
urng(10, 60, 1000)
# Out:
# array([52.09516919, 53.34512428, 45.82867741, 16.01521995, 38.19859924,
#        43.38696929, 23.35373202, 50.55022451, 30.79230584, 59.25175083,
#        54.34365795, 31.30431147, 17.78055956, 13.34663778, 56.89501691,
#        41.5468316 , 48.56543978, 57.86385784, 13.86426484, 17.68716019,
#        19.89042416, 24.35472072, 17.25093435, 50.91381616, 49.93155964,
#        57.03368947, 22.99743438, 43.02075122, 28.75316089, 43.42784808,
#        31.85389591, 42.5422722 , 15.24474388, 43.77510813, 17.10708918,
#        17.75857882, 38.18003844, 22.9616354 , 10.11458618, 35.93464807,
#        30.52623329, 37.14724609, 11.43389473, 13.31106743, 50.38580005,
#        24.86872804, 16.69075914, 25.32362035, 49.04161922, 17.16737874,
#        12.46273966, 17.79880475, 21.31318296, 25.87073991, 22.13490031,
#        21.52893752, 14.55069626, 15.92596162, 34.09587999, 26.20476428,
#        13.80529894, 22.52357079, 33.90910546, 47.01657988, 19.81732206,
# ...

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (22,12)

fig, axes = plt.subplots(1,2, sharey=True)

# The range and the frequencies are greater for the second plot.
axes[0].hist(urng(10, 15, 100));
axes[1].hist(urng(10, 60, 1000));

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
# your code here

fig, axes = plt.subplots(1,2, sharey=True)

axes[0].hist(np.random.normal(10,1,1000), bins=100);
axes[1].hist(np.random.normal(10,50,1000), bins=100);

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below
# The second distribution (to the right) has a bigger range, thus it has more dispersion.

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
# your code here
data = pd.read_csv('vehicles.csv')
data.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
fig, axes = plt.subplots(1,3, sharey=True)

data['Fuel Barrels/Year'].hist(bins=15, ax=axes[0]);
data['CO2 Emission Grams/Mile'].hist(bins=15, ax=axes[1]);
data['Combined MPG'].hist(bins=15, ax=axes[2]);

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
# your answer here

# A normality test can be made with the normaltest function from scipy
from scipy.stats import normaltest

# %%
# An array of data can be considered normaly distributed if the resulted p-value is less than 1e3

print(f"Fuel Barrels/Year p-value is less than 0.001?: {normaltest(data['Fuel Barrels/Year'])[1]<1e3}")
print(f"CO2 Emission Grams/Mile p-value is less than 0.001?: {normaltest(data['CO2 Emission Grams/Mile'])[1]<1e3}")
print(f"Combined MPG p-value is less than 0.001?: {normaltest(data['Combined MPG'])[1]<1e3}")
# Out:
# Fuel Barrels/Year p-value is less than 0.001?: True
# CO2 Emission Grams/Mile p-value is less than 0.001?: True
# Combined MPG p-value is less than 0.001?: True

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 1 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
# your code here
fig, axes = plt.subplots(1,2, sharey=True)

axes[0].hist(np.random.exponential(10,1000), bins=100);
axes[1].hist(np.random.exponential(100,1000), bins=100);

# %% [markdown]
# How are the two distributions different?

# %%
# your answer here
# The difference lies in the range, it is wider in the one with the mean of 100 (to the right).

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
# your answer here
# Hint: This is same as saying P(x<15)
print(f"The probability that a customer will spend less than fifteen minutes in the bank is {sum(np.random.exponential(10,1000)<=15)/10} %")
# Out:
# The probability that a customer will spend less than fifteen minutes in the bank is 79.5 %

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
# your answer here
print(f"The probability that a customer will spend more than fifteen minutes in the bank is {100-79.5} %")
# Out:
# The probability that a customer will spend more than fifteen minutes in the bank is 20.5 %
