# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
from scipy.stats import uniform, norm, expon
import numpy as np
import matplotlib.pyplot as plt
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(x)
# Out:
# [0.5194233  0.48098686 0.44843768 0.29203781 0.50085308 0.64743814
#  0.99477564 0.82952907 0.86776717 0.16019792]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
# your code here
def uniform_generator(bottom,ceiling,count):
    random_sample = uniform.rvs(size=count)
    random_uniformed_distribuited  = bottom + (ceiling - bottom) * random_sample
    return random_uniformed_distribuited

exercise_1 = uniform_generator(10, 15, 100)
exercise_2 = uniform_generator(10, 60, 1000)


fig, (ax1, ax2) = plt.subplots(1, 2,  sharey=True)
ax1.hist(exercise_1, bins=10);
ax2.hist(exercise_2, bins=10);

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below
# El conteo de las

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
# your code here
def normal_distribution(mean_,stdev, count):
    normal = norm(mean_, stdev)
    normal_sample = normal.rvs(size=count)
    return normal_sample

exercise_3 = normal_distribution(10,1,1000)
exercise_4 = normal_distribution(10,50,1000)

fig, (ax3, ax4) = plt.subplots(1, 2,  sharey=True)
ax3.hist(exercise_3, bins=60)
ax4.hist(exercise_4, bins=60);

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
# your code here
import pandas as pd
import seaborn as sns 
from scipy.stats import norm

vehicles = pd.read_csv('vehicles.csv')

sns.distplot(vehicles['Fuel Barrels/Year'], fit=norm);
# Out:
# /Users/franciscoponce/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
# your code here
sns.distplot(vehicles['CO2 Emission Grams/Mile'], fit=norm);
# Out:
# /Users/franciscoponce/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# 3. Combined MPG

# %%
# your code here
sns.distplot(vehicles['Combined MPG'], fit=norm);
# Out:
# /Users/franciscoponce/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
# your answer here
# Pareciera que el rendimiento combinado de millas por galón se asemeha más a una distribución normal

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 1 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
# your code here

def exponential_generator(size, mean):
    return np.random.exponential(size=size) * mean

number_1 = exponential_generator(1000, 10)
number_2 = exponential_generator(1000, 10)

fig, (ax3, ax4) = plt.subplots(1, 2)
ax3.hist(number_1, bins=100)
ax4.hist(number_2, bins=100);

# %% [markdown]
# How are the two distributions different?

# %%
# your answer here

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
# your answer here
# Hint: This is same as saying P(x<15)
# https://openstax.org/books/introducci%C3%B3n-estad%C3%ADstica-empresarial/pages/5-3-la-distribucion-exponencial#:~:text=P%20(%20x%20)%20%3D%20%CE%BC%20x,el%20crecimiento%20o%20decaimiento%20exponencial.

lambda_=1/10
parametro_decaimiento = 15
exp_prob = 1 - np.exp(-lambda_*parametro_decaimiento)

exp_prob

x = np.linspace(0,50,100)
y = expon.pdf(x, scale=10)

plt.plot(x,y)

expon.cdf(x=15, scale=10) == exp_prob
# Out:
# True

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
# your answer here

# %%
1 - expon.cdf(x=15, scale=10)
# Out:
# 0.2231301601484298
