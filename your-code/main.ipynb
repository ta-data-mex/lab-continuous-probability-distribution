# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import uniform

# %%
from scipy.stats import uniform
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.66216268 2.89610174 2.25538212 2.73387824 2.67979989 2.89617397
#  2.70127745 2.43230469 2.04555132 2.10815315]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
# your code here
parameters_1 = [10,15,100]
parameters_2 = [10,60,1000]
def uniform_distribution(lista):
    return uniform.rvs(lista[0], lista[1], lista[2])

u_dist_1 = uniform_distribution(parameters_1)
u_dist_2 = uniform_distribution(parameters_2)

fig, ax = plt.subplots(1,2, sharey=True)
ax[0].hist(u_dist_1, bins = 10)
ax[1].hist(u_dist_2, bins = 10);

# %% [markdown]
# How are the two distributions different?

# %%
# your answer belo
# Importing necesary added libraries
from scipy.stats import norm
import math
# printing base parameters
print(f'mean = {u_dist_1.mean()}')
print(f'sigma = {math.sqrt(u_dist_1.var())}')

# calculating base parameters
mean = u_dist_1.mean()
stdev = math.sqrt(u_dist_1.var())

plt.figure(figsize=(10, 5))

x = np.linspace(mean-(4*stdev), mean+(4*stdev), 1_000)
y = norm.pdf(x, mean, stdev)

plt.plot(x, y)

colors = ['r', 'y', 'g']

for i in range(1, 4):
  plt.vlines([mean+i*stdev, mean-i*stdev], 0, norm.pdf(mean+i*stdev, mean, stdev),
             colors=colors[i-1], lw=2, linestyles='dashed')
plt.show();
# Out:
# mean = 17.6872041311125
# sigma = 4.206055023382077

# %%
# Importing necesary added libraries
from scipy.stats import norm
import math
# printing base parameters
print(f'mean = {u_dist_2.mean()}')
print(f'sigma = {math.sqrt(u_dist_2.var())}')

# calculating base parameters
mean = u_dist_2.mean()
stdev = math.sqrt(u_dist_2.var())

plt.figure(figsize=(10, 5))

x = np.linspace(mean-(4*stdev), mean+(4*stdev), 1_000)
y = norm.pdf(x, mean, stdev)

plt.plot(x, y)

colors = ['r', 'y', 'g']

for i in range(1, 4):
  plt.vlines([mean+i*stdev, mean-i*stdev], 0, norm.pdf(mean+i*stdev, mean, stdev),
             colors=colors[i-1], lw=2, linestyles='dashed')
plt.show();
# Out:
# mean = 39.29190914883701
# sigma = 17.424577019601546

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
# your code here
from scipy.stats import norm
import math
# norm function needs size=number of elements, loc=mean of elements, scale=stdev of elements
normal_distribution_1 = norm.rvs(size=1000, loc=10, scale=1)
normal_distribution_2 = norm.rvs(size=1000, loc=10, scale=50)

fig, axs = plt.subplots(1, 2, sharey=True, tight_layout=True)

# We can set the number of bins with the *bins* keyword argument.
axs[0].hist(normal_distribution_1, bins=50);
axs[1].hist(normal_distribution_2, bins=50);

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below
df_1 = pd.DataFrame(normal_distribution_1)
df_2 = pd.DataFrame(normal_distribution_2)
df_info = pd.concat([df_1,df_2], axis=1)
df_info.describe()
# Out:
#                  0            0
# count  1000.000000  1000.000000
# mean      9.962263     9.198181
# std       1.013934    51.555722
# min       6.379263  -168.931350
# 25%       9.244955   -26.354609
# 50%       9.972944     9.555238
# 75%      10.720317    44.162253
# max      13.225682   176.009080

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:

# %%
# your code here
import pandas as pd
import numpy as np
vehicles = pd.read_csv('vehicles.csv')
vehicles.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
# your code here
import seaborn as sns

fig, axs = plt.subplots(1, 1, figsize=(5,5), tight_layout=True)
axs = sns.distplot(vehicles['Fuel Barrels/Year'], fit=norm);
fig, axs = plt.subplots(1, 1, figsize=(5,5), tight_layout=True)
axs = sns.distplot(vehicles['CO2 Emission Grams/Mile'], fit=norm);
fig, axs = plt.subplots(1, 1, figsize=(5,5), tight_layout=True)
axs = sns.distplot(vehicles['Combined MPG'], fit=norm);
# Out:
# C:\Users\JoseV\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\JoseV\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
# your answer here
fig, axs = plt.subplots(1, 1, figsize=(5,5))

# We can set the number of bins with the *bins* keyword argument.
axs.hist(vehicles['Fuel Barrels/Year'], bins=50)
x = np.linspace(norm.ppf(vehicles['Fuel Barrels/Year']).min(), norm.ppf(vehicles['Fuel Barrels/Year']).max(), 100)
axs.plot(x, norm.pdf(x), 'k-', lw=2, label='frozen pdf');

# This code did not work properly since the plot part for the normal distribution was not printed in the graph correctly

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 100 and 1000.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
# your code here
exponential_sequence_100 = np.random.exponential(100, 1000)
exponential_sequence_1000 = np.random.exponential(1000, 1000)
fig, axs = plt.subplots(1, 2, figsize=(10,5))

# We can set the number of bins with the *bins* keyword argument.
axs[0].hist(exponential_sequence_100, bins=100)
axs[1].hist(exponential_sequence_1000, bins=100);

# %% [markdown]
# How are the two distributions different?

# %%
# your answer here
# Distribution nr 2 has more dispertion and appears to be more shaped to an uniformed exponential curve

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
# your answer here
# Hint: This is same as saying P(x<15)
def probability(lambda_x, time_period):
    return math.exp(-lambda_x * time_period)

lambda_x = 1/10 # lambda=(1/mean time)
time_period = 15
info_str = 'Chances of a customer being attended in less than {0} minutes: {1}'
print(info_str.format(time_period, 1-probability(lambda_x, time_period)))

step = 0.01
whole_x = np.arange(0, 20, step)
whole_y = [probability(lambda_x, x) for x in whole_x]

needed_x = np.arange(0, 15, step)
needed_y = whole_y[:len(needed_x)]

plt.plot(whole_x, whole_y)
plt.fill_between(needed_x, needed_y)
plt.ylabel('Chances from 0 to 1')
plt.xlabel('Estimated line-waiting for customers')

plt.show();
# Out:
# Chances of a customer being attended in less than 15 minutes: 0.7768698398515702

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
# your answer here
lambda_x = 1/10
time_period = 15
info_str = 'Chances of a customer being attended in more than {0} minutes: {1}'
print(info_str.format(time_period, probability(lambda_x, time_period)))

step = 0.01
whole_x = np.arange(0, 20, step)
whole_y = [probability(lambda_x, x) for x in whole_x]

needed_x = np.arange(15,20, step)
needed_y = whole_y[1500:]   # as the lenght in x has changed from 0 to 15, the needed_y values
                            # must meet the same size as needed x values, in this case 500 hundred list elements

plt.plot(whole_x, whole_y)
plt.fill_between(needed_x, needed_y)
plt.ylabel('Chances from 0 to 1')
plt.xlabel('Estimated line-waiting for customers')

plt.show();
# Out:
# Chances of a customer being attended in more than 15 minutes: 0.22313016014842982
